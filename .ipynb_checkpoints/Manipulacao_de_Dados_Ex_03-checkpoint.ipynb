# %% [markdown]
# ![](https://i.imgur.com/JsMvGnP.png)

# %% [markdown]
# ## Exercícios de manipulação de dados - Parte 3

# %% [markdown]
# Neste Jupyter notebook você irá resolver uma exercícios utilizando a linguagem Python e a biblioteca Pandas.
#
# Todos os datasets utilizados nos exercícios estão salvos na pasta **datasets**.
#
# Todo o seu código deve ser executado neste Jupyter Notebook. Por fim, se desejar, revise as respostas com o seu mentor.

# %% [markdown]
# ### Tarefa 1. Importe o dataset e salve os dados em um dataframe
#
# Os dados estão salvos no arquivo ***datasets/users_dataset.txt***.
#
# Salve os dados em uma variável de nome *users*.

# %%
import pandas as pd

users = pd.read_csv('datasets/users_dataset.csv',sep='|')

# %% [markdown]
# ### Tarefa 2. Descubra qual a idade média por ocupação.
#
# *Dica: use a função groupby do Pandas na coluna occupation*

# %%
# Seu código
users.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Tarefa 3. Para cada ocupação descubra a idade mínima e máxima.

# %%
users.groupby('occupation')['age'].agg(['max','min'])
# Out:
#                max  min
# occupation
# administrator   70   21
# artist          48   19
# doctor          64   28
# educator        63   23
# engineer        70   22
# entertainment   50   15
# executive       69   22
# healthcare      62   22
# homemaker       50   20
# lawyer          53   21
# librarian       69   23
# marketing       55   24
# none            55   11
# other           64   13
# programmer      63   20
# retired         73   51
# salesman        66   18
# scientist       55   23
# student         42    7
# technician      55   21
# writer          60   18

# %% [markdown]
# ### Tarefa 4. Para cada combinação de ocupação e sexo, calcule a idade média.
#
# Exemplo:
#
# ```
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# ```

# %%
users.groupby(['occupation','gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
#                M         34.028986
# programmer     F         32.166667
#                M         33.216667
# retired        F         70.000000
#                M         62.538462
# salesman       F         27.000000
#                M         38.555556
# scientist      F         28.333333
#                M         36.321429
# student        F         20.750000
#                M         22.669118
# technician     F         38.000000
#                M         32.961538
# writer         F         37.631579
#                M         35.346154
# Name: age, dtype: float64

# %% [markdown]
# ### Tarefa 5. Para cada ocupação calcule a porcentagem de homens e mulheres.
#
# Exemplo:
#
# ```
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# ```

# %%
users_2 = pd.DataFrame(users.groupby(['occupation','gender'])['age'].count())
users_2.groupby(level=0).transform(lambda x: (x / x.sum()).round(5))
# Out:
#                           age
# occupation    gender
# administrator F       0.45570
#               M       0.54430
# artist        F       0.46429
#               M       0.53571
# doctor        M       1.00000
# educator      F       0.27368
#               M       0.72632
# engineer      F       0.02985
#               M       0.97015
# entertainment F       0.11111
#               M       0.88889
# executive     F       0.09375
#               M       0.90625
# healthcare    F       0.68750
#               M       0.31250
# homemaker     F       0.85714
#               M       0.14286
# lawyer        F       0.16667
#               M       0.83333
# librarian     F       0.56863
#               M       0.43137
# marketing     F       0.38462
#               M       0.61538
# none          F       0.44444
#               M       0.55556
# other         F       0.34286
#               M       0.65714
# programmer    F       0.09091
#               M       0.90909
# retired       F       0.07143
#               M       0.92857
# salesman      F       0.25000
#               M       0.75000
# scientist     F       0.09677
#               M       0.90323
# student       F       0.30612
#               M       0.69388
# technician    F       0.03704
#               M       0.96296
# writer        F       0.42222
#               M       0.57778

# %%
# Out:
# Object `DataFrame.count` not found.

# %% [markdown]
# **Parabéns! Você chegou ao fim!**
